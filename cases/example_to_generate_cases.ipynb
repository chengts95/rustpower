# %%
import pandapower as pp
import  pandapower.networks as nets

# %%
net = nets.case118()

# %%
def to_csv(net):
    #the sn_mva and f_hz are not included in csv files!
    net.bus.to_csv("bus.csv",index_label="index")
    net.line.to_csv("line.csv",index=False)
    net.load.to_csv("load.csv",index=False)
    net.gen.to_csv("gen.csv",index=False)
    net.shunt.to_csv("shunt.csv",index=False)
    net.trafo.to_csv("trafo.csv",index=False)
    net.ext_grid.to_csv("extgrid.csv",index=False)

# %%
to_csv(net)

# %%
net.res_bus
# Out:
#         vm_pu  va_degree        p_mw     q_mvar
# 0    0.955000  10.972367   51.000000  30.104097
# 1    0.971393  11.512175   20.000000   9.000000
# 2    0.967692  11.855817   39.000000  10.000000
# 3    0.998000  15.573717   39.000000  27.009646
# 4    1.001985  16.018806    0.000000  40.158928
# 5    0.990000  13.291499   52.000000   6.070234
# 6    0.989328  12.846965   19.000000   2.000000
# 7    1.015000  21.040211   28.000000 -63.138428
# 8    1.042918  28.294316    0.000000   0.000000
# 9    1.050000  35.875226 -450.000000  51.042152
# 10   0.985089  13.005428   70.000000  23.000000
# 11   0.990000  12.488539  -38.000000 -81.291736
# 12   0.968302  11.629375   34.000000  16.000000
# 13   0.983591  11.771086   14.000000   1.000000
# 14   0.970000  11.473775   90.000000  22.839548
# 15   0.983897  12.186966   25.000000  10.000000
# 16   0.995089  13.994850   11.000000   3.000000
# 17   0.973000  11.780421   60.000000   5.573677
# 18   0.962000  11.314277   45.000000  39.274169
# ...
